# %%
import numpy as np
import sqlite3
import pandas as pd
import re
import tarfile as tf
import quantities as pq
import xml.etree.ElementTree as et
import pdb
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import PCA
from sklearn.decomposition import FastICA
from scipy.ndimage import gaussian_filter1d
from scipy import stats

def regexp(expr, item):
    reg = re.compile(expr)
    return reg.search(item) is not None

class ReadSession:
    def __init__(self,
                 dataset,
                 path,
                 animal_id,
                 day,
                 beh,
                 session,
                 unit_spiketime,
                 unit_space,
                 unit_lfp=pq.V,
                 load_lfp=False):

        meta_path = path + dataset + '/docs/' + dataset.replace('-', '') +\
                    '-metadata-tables/' + dataset.replace('-', '') +\
                    '-tables.db'

        # Open database
        con_sessions = sqlite3.connect(meta_path)
        con_sessions.create_function("REGEXP", 2, regexp)

        topdir = animal_id 
        subdir = str(session)
        
        df_session = pd.read_sql_query(
            'SELECT ' +
            'topdir, ' +
            'session, ' +
            'behavior, ' +
            'familiarity, ' +
            'duration ' +
            'from session where behavior=\'' +
            beh +
            '\' AND session=\'' +
            subdir +
            '\' AND topdir=\'' +
            topdir +
            '\'', con_sessions)

        df_cells = pd.read_sql_query(
            'SELECT ' +
            'id, ' +
            'topdir, ' +
            'animal, ' +
            'ele, ' +
            'clu, ' +
            'region, ' +
            'nexciting, ' +
            'ninhibiting, ' +
            'exciting, ' +
            'inhibiting, ' +
            'excited, ' +
            'inhibited, ' +
            'fireRate, ' +
            'totalFireRate, ' +
            'cellType ' +
            'From cell where topdir REGEXP \'' +
            topdir + '\'',
            con_sessions)
        
        df_epos = pd.read_sql_query(
            'SELECT ' +
            'topdir, ' +
            'animal, ' +
            'e1, ' +
            'e2, ' +
            'e3, ' +
            'e4, ' +
            'e5, ' +
            'e6, ' +
            'e7, ' +
            'e8, ' +
            'e9, ' +
            'e10, ' +
            'e11, ' +
            'e12, ' +
            'e13, ' +
            'e14, ' +
            'e15, ' +
            'e16 ' +
            'From epos where topdir REGEXP \'' +
            topdir + '\'',
            con_sessions)
        
        electrode_ids = np.unique(df_cells['ele'])
        path_to_session = path + dataset + '/' + \
            topdir + '/' +\
            subdir + '.tar.gz'

        # extract variables from data
        clusters = {}
        times = {}
        with tf.open(path_to_session) as tf_session:
            # get sampling rate of spike timestamps

            xml_f = tf_session.extractfile(
                topdir + '/' +
                subdir + '/' +
                subdir + '.xml')
            e = et.parse(xml_f).getroot()
            sampling_rate_spike_time = float(
                e.findall("./acquisitionSystem/samplingRate")[0].text)

            # get animal position
            # positions_file = tf_session.extractfile(
            #     topdir + '/' +
            #     subdir + '/' +
            #     subdir + '.whl')
            # positions_file_lines =[np.array(line.split(), dtype=np.float64) for line in positions_file.readlines()]
    
            # positions = np.stack(positions_file_lines)
            
            
            for ele_i in electrode_ids:
                clusters_f = tf_session.extractfile(
                    topdir + '/' +
                    subdir + '/' +
                    subdir + '.clu.' + str(ele_i))
                # read cluster file
                clusters_i = np.array([int(clu_id) for clu_id in clusters_f ])
                # first line contains number of clusters in file, skip it
                
                
                clusters_i = clusters_i[1:]
                
                times_f = tf_session.extractfile(
                    topdir + '/' +
                    subdir + '/' +
                    subdir + '.res.' + str(ele_i))
                # get times of spikes
                times_i= np.array([float(time_j) for time_j in times_f])*unit_spiketime
                # divide by sampling rate
                times_i /= sampling_rate_spike_time
                
                # from documentation:
                # cluster 0 corresponds to mechanical noise (the wave shapes
                # do not look like neuron's spike). Cluster 1 corresponds to
                # small, unsortable spikes. These two clusters (0 and 1) should
                # not be used for analysis of neural data since they do not
                # correspond to successfully sorted spikes.

                # remove clusters == 0 and == 1
                pos_cluster_not_0_or_1 = np.where(clusters_i >= 2)[0]
                clusters_i = clusters_i[pos_cluster_not_0_or_1]
                times_i = times_i[pos_cluster_not_0_or_1]
                clusters[ele_i] = clusters_i
                times[ele_i] = times_i

                    
       # positions = positions * unit_space
        
        def data_spikes(electrode_ids,clusters,times):
            combined_arrays = []
            electrodeids = []
            for i in electrode_ids:
                combined_spike_time_i=np.column_stack((clusters[i],times[i]))
                combined_arrays.append(combined_spike_time_i)
                electrodeids_i = np.full((combined_spike_time_i.shape[0], 1), i)
                electrodeids.append(electrodeids_i)


            combined_array_all = np.vstack(
                [np.hstack((electrodeids[i], combined_arrays[i])) for i in range(len(electrode_ids))]
            )

            df = pd.DataFrame(data=combined_array_all, columns=['Electrode ID', 'Cluster', 'Time'])
            return df

        self.df_session = df_session
        self.df_cells = df_cells
        self.dataset = dataset
        self.path = path
        self.animal_id = animal_id
        self.day = day
        self.beh = beh
        self.session = session
        self.unit_spiketime = unit_spiketime
        self.unit_space = unit_space
        self.data_spikes= data_spikes(electrode_ids, clusters, times)

        
        
def count_spikes_per_neurons(df, time_bins):
    neurons_counts = []
    for bin_start, bin_end in zip(time_bins[:-1], time_bins[1:]):
        bin_counts = df[(df['Time'] >= bin_start) & (df['Time'] < bin_end)].groupby(['region', 'Electrode ID','Cluster']).count()['Time']
        neurons_counts.append(bin_counts)
    return pd.concat(neurons_counts, axis=1, keys=time_bins[:-1])

dataset = "hc-3"
path = "D:/37/"
animal_id = "ec016.45"
day = 749
beh = "linear"
session = "ec016.749"
unit_spiketime = pq.ms
unit_space = pq.mm
load_lfp = False  # no need to set True!

data=ReadSession(dataset,path,animal_id,day,beh,session,unit_spiketime,unit_space,load_lfp)

spike_time=data.data_spikes #get spikes and their times
cell=data.df_cells #get type of neurons and regions 
session_len= data.df_session

merged_df =spike_time.merge(cell, left_on=['Electrode ID', 'Cluster'], right_on=['ele', 'clu'], how='left')
drop_list=['id', 'topdir', 'animal', 'ele','clu', 'fireRate','nexciting','ninhibiting',
           'exciting', 'inhibiting', 'excited', 'inhibited', 'totalFireRate']
spike_time_cell= merged_df.drop(columns=drop_list,axis=1) #mix all: type cell, spikes, regions, clusters and electrod ids
#print(spike_time_cell.head)


bin_width = 5
start_time = 0  
end_time = session_len.loc[0,'duration']
time_bins = np.arange(start_time, end_time + bin_width, bin_width)

spikes_counts_per_neurons = count_spikes_per_neurons(spike_time_cell, time_bins).fillna(0).transpose()
spikes_counts_per_neurons_sorted = spikes_counts_per_neurons.sort_index(axis=1, level=[0, 1, 2])


CA3_cells = spikes_counts_per_neurons_sorted.xs(key='CA3', level='region', axis=1, drop_level=False)
EC2_cells = spikes_counts_per_neurons_sorted.xs(key='EC2', level='region', axis=1, drop_level=False)
EC5_cells = spikes_counts_per_neurons_sorted.xs(key='EC5', level='region', axis=1, drop_level=False)

CA3_correlation_matrix = CA3_cells.corr()
EC2_correlation_matrix = EC2_cells.corr()
EC5_correlation_matrix = EC5_cells.corr()

# %%
    ## CA3

plt.figure(figsize=(20, 20))
mask = np.triu(np.ones_like(CA3_correlation_matrix, dtype=bool))
sns.heatmap(CA3_correlation_matrix, cmap='coolwarm', annot=False, fmt=".2f", mask=mask, cbar_kws={'label': 'Correlation'})
plt.title('Animal: ec016.45 and behavior: Sleep /// Correlation Map of CA3 cells: through each time bins')
plt.show()

    ##EC2

plt.figure(figsize=(20, 20))
mask = np.triu(np.ones_like(EC2_correlation_matrix, dtype=bool))
sns.heatmap(EC2_correlation_matrix, cmap='coolwarm', annot=False, fmt=".2f", mask=mask, cbar_kws={'label': 'Correlation'})
plt.title('Animal: ec016.45 and behavior: Sleep /// Correlation Map of EC2 cells: through each time bins')
plt.show()


    ##EC5

plt.figure(figsize=(20, 20))
mask = np.triu(np.ones_like(EC5_correlation_matrix , dtype=bool))
sns.heatmap(EC5_correlation_matrix, cmap='coolwarm', annot=False, fmt=".2f", mask=mask, cbar_kws={'label': 'Correlation'})
plt.title('Animal: ec016.45 and behavior: Sleep /// Correlation Map of EC5 cells: through each time bins')
plt.show()

# %%
### Average Corr for each Region:
    
average_correlation_CA3 = np.mean(CA3_correlation_matrix.values)
average_correlation_EC2 = np.mean(EC2_correlation_matrix.values)
average_correlation_EC5 = np.mean(EC5_correlation_matrix.values)

print('average_correlation_CA3:',average_correlation_CA3 )
print('average_correlation_EC2:',average_correlation_EC2 )
print('average_correlation_EC5:',average_correlation_EC5 )
# Out:
# average_correlation_CA3: 0.10674837693044052
# average_correlation_EC2: 0.164199371164102
# average_correlation_EC5: 0.6148841578659358

# %%
def assebmlypatterns(data_cell,nameofregion):
    
    '''PCA'''
    scaler = StandardScaler()
    scaled = scaler.fit_transform(data_cell)
    pca = PCA(n_components = len(data_cell.columns))
    pcomp= pca.fit_transform(scaled)
    components=pca.components_
    eigenvalues = pca.explained_variance_
    #threshold for eigensvalus
    
    n=len(data_cell.columns) # number of neurons 
    B=len(data_cell.index) # number of bins
    LamdaMAX=(1+(np.sqrt(n/B)))**2
    LamdaMIN=(1-(np.sqrt(n/B)))**2
    distinct_significant_patterns=np.column_stack(np.where(eigenvalues>= LamdaMAX))
    component_numbers = np.arange(1, len(components) + 1)
    
    num_bins_eigens = 15
    min_value = np.min(eigenvalues)
    max_value = np.max(eigenvalues)
    bin_edges = np.linspace(min_value, max_value, num_bins_eigens + 1)
    
    # Create a histogram
    hist, bin_edges = np.histogram(eigenvalues, bins=bin_edges)
    
    
    plt.figure(figsize=(10, 6))
    
    for i in range(num_bins_eigens):
        color = 'pink' if bin_edges[i] > LamdaMAX else 'skyblue'
        plt.bar(bin_edges[i], hist[i], width=bin_edges[i + 1] - bin_edges[i], align='edge', edgecolor='black', color=color)
    
    plt.xlabel('Eigenvalue Bins')
    plt.ylabel('Number of Components')
    plt.title('Histogram of Eigenvalues')
    plt.axvline(LamdaMAX, linestyle='--', color='red', label=f'LamdaMAX: {LamdaMAX}')
    plt.axvline(LamdaMIN, linestyle='--', color='black', label=f'LamdaMIN: {LamdaMIN}')
    
    plt.legend()
    plt.show()


    '''ICA'''
    psign=components[:len(distinct_significant_patterns)]
    projMatica = (psign @ scaled.T)
    ica = FastICA(n_components=len(distinct_significant_patterns), random_state=0)
    icac=ica.fit(projMatica.T)
    comp_weight = ica.components_
    V=(psign.T @ comp_weight).T
    num_components = V.shape[0]
    plt.figure(figsize=(12, 2*num_components))

    colors = plt.cm.viridis(np.linspace(0, 1, V.shape[1]))
    
    for i in range(num_components):
        plt.subplot(num_components, 1, i+1)
        
        # Find neurons whose weight exceeds mean + 2 * std
        threshold = np.mean(V[i, :]) + 2 * np.std(V[i, :])
        highlighted_neurons = np.where(V[i, :] > threshold)[0]
        
    
        if i == 0:
            plt.stem(V[i, :], label=f"IC {i+1}", linefmt='k-', markerfmt='ko', basefmt='k-')
            if len(highlighted_neurons) !=0:
                plt.stem(highlighted_neurons, V[i, highlighted_neurons], linefmt='r-', markerfmt='ro', basefmt='k-')
    
                plt.title(f"Independent Component {i+1}")
                plt.xlabel("Neurons of "+ nameofregion)
                plt.ylabel("Weight")
                
            else:
                print('No neurons meet the threshold  for highlighting. In IC number:', i+1)
        
        else:
            plt.stem(V[i, :], label=f"IC {i+1}", linefmt='k-', markerfmt='ko', basefmt='k-')
            if len(highlighted_neurons)>0:
                plt.stem(highlighted_neurons, V[i, highlighted_neurons], linefmt='b-', markerfmt='bo', basefmt='k-')
                plt.title(f"Independent Component {i+1}")
                plt.xlabel("Neurons of "+nameofregion)
                plt.ylabel("Weight")
            else:
                print('No neurons meet the threshold  for highlighting. In IC number:', i+1)
    
    plt.tight_layout()
    plt.show()
    
        
    '''Strenghth assem'''
        
    smoothed = gaussian_filter1d(data_cell, sigma=25/np.sqrt(12))
    smoothed_z = scaler.fit_transform(smoothed)
    assemblystr = np.zeros((num_components, B))
    
    for i in range(num_components):
    
        projMat = np.outer(V[i ,:], V[i ,:])
        if True:
            np.fill_diagonal(projMat, 0)
    
        assemblystr[i, :] = np.nansum(smoothed_z @ projMat * smoothed_z, axis=1)
    
    plt.figure(figsize=(20, 15))
    for i in range(num_components):
        plt.plot(assemblystr[i, :], label=f'Assembly Pattern {i+1}')

    plt.title("Assembly Pattern Expression Strength over Time")
    plt.xlabel("Time")
    plt.ylabel("Expression Strength")
    plt.legend()
    plt.show()
        
    plt.figure(figsize=(20, 15))
    for i in range(num_components):
        plt.subplot(num_components, 1, i+1)
    
        # Plot the assembly pattern expression strength over time
        plt.plot(assemblystr[i, :], label=f'Assembly Pattern {i+1}')
    
        plt.title(f"Assembly Pattern {i+1} Expression Strength over Time")
        plt.xlabel("Time")
        plt.ylabel("Expression Strength")
        plt.legend()
    
    plt.tight_layout()
    plt.show()

    return eigenvalues, V,smoothed_z, assemblystr

eigenvalue, Vectors, smoothed_zr, assemblies_strength_CA3= assebmlypatterns(CA3_cells, 'CA3')
# Out:
# No neurons meet the threshold  for highlighting. In IC number: 1
# No neurons meet the threshold  for highlighting. In IC number: 2
# No neurons meet the threshold  for highlighting. In IC number: 3
